# %%
import os
os.chdir(r"/Users/Greer/Desktop/Lending Club - JL")

# %%
##### IMPORT ONE CSV
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("LoanStats_2016Q1.csv",skiprows=1, low_memory=False)
df1.head()
len(df1)
# 2016Q1: 133889 observations, 111 columns/attributes

df2 = pd.read_csv("LoanStats_2016Q2.csv",skiprows=1, low_memory=False)
df2.head()
len(df2)
# 2016Q2: 97856 observations, 111 columns/attributes

df3 = pd.read_csv("LoanStats_2016Q3.csv",skiprows=1, low_memory=False)
df3.head()
len(df3)
# 2016Q3: 99122 observations, 111 columns/attributes
# Out:
# 99122

# %%
list(df3)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
df16 = df1.append([df2, df3])

### Write combined dataframe to CSV
df16.to_csv('LendingClub-2016AllLoans.csv')

# %%
len(df16)
# Out:
# 330867

# %%
list(df16)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
df16.head()
# Out:
#          id   member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  75607431  81042152.0    10000.0      10000.0          10000.0   36 months
# 1  75779347  81247087.0    25000.0      25000.0          25000.0   36 months
# 2  76132672  81623431.0    15000.0      15000.0          15000.0   36 months
# 3  76061568  81552293.0    18000.0      18000.0          18000.0   36 months
# 4  76102531  81593275.0     3000.0       3000.0           3000.0   36 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0   11.47%       329.62     B        B5            ...
# 1   15.31%       870.44     C        C5            ...
# 2   11.47%       494.43     B        B5            ...
# 3   12.99%       606.41     C        C2            ...
# 4    7.39%        93.17     A        A4            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                0.0                3.0           68.7              75.0
# ...
